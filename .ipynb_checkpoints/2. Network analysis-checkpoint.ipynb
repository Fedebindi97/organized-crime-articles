# %% [markdown]
# # Packages

# %%
import pandas as pd
import numpy as np
import itertools
import networkx as nx
import pyvis

# %% [markdown]
# # Individuals

# %% [markdown]
# ## Network preparation

# %%
df_individuals = pd.read_csv('_aux/Individuals.csv')

# %%
df_articles = pd.read_csv('_raw/Articles.csv')

# %%
df_articles
# Out:
#                                                     text lang
# 0      EPL Muscles in on El Naya Drug Corridor in Wes...   en
# 1      Campaign Group Warns of Dangers for Colombia E...   en
# 2      InSight: Report Tracks How Intra-Cartel Wars E...   en
# 3      Colombia Cocaine Production Breaks New Record ...   en
# 4      US Marijuana Vote Unlikely to Impact Mexico in...   en
# ...                                                  ...  ...
# 19935  Presencia de pandillas en Tegucigalpa. La exto...   es
# 19936  Pandillas callejeras. Las conocidas pandillas ...   es
# 19937  Imitadores. Mediante la violencia, la Mara Sal...   es
# 19938  ABC de la extorsión 3: El modus operandi. Un t...   es
# 19939  Presencia de pandillas en San Pedro Sula. San ...   es
#
# [19940 rows x 2 columns]

# %%
df_individuals
# Out:
#                                   name           alias_1 alias_2  \
# 0   Héctor Rusthenford Guerrero Flores     Niño Guerrero     NaN
# 1          Hermágoras González Polanco  Gordito González     NaN
# 2                        Yeico Masacre               NaN     NaN
# 3                   Genaro García Luna               NaN     NaN
# 4          Gilberto Rodríguez Orejuela  The Chess Player     NaN
# ..                                 ...               ...     ...
# 86        Miguel Angel Treviño Morales               Z40     NaN
# 87                   Diego Perez Henao    Diego Rastrojo     NaN
# 88                 Luis E. Calle Serna               NaN     NaN
# 89          Javier Antonio Calle Serna             Comba     NaN
# 90         Guillermo Leon Saenz Vargas      Alfonso Cano     NaN
#
#             first_name         family_name
# 0   Héctor Rusthenford     Guerrero Flores
# 1           Hermágoras    González Polanco
# 2                Yeico             Masacre
# 3               Genaro         García Luna
# 4             Gilberto  Rodríguez Orejuela
# ..                 ...                 ...
# 86        Miguel Angel     Treviño Morales
# 87               Diego         Perez Henao
# 88        Luis Enrique         Calle Serna
# 89      Javier Antonio         Calle Serna
# 90      Guillermo Leon        Saenz Vargas
#
# [91 rows x 5 columns]

# %% [markdown]
# "Úsuga" and "Calle Serna" are duplicated family names (2 copies each). Both the two "Úsuga" and the two "Calle Serna" are brothers. Hence, for them the search term will be the whole name, while for other criminals it will just be the family name.

# %%
df_individuals['search_term'] = np.where((df_individuals.family_name=="Úsuga") | (df_individuals.family_name=="Calle Serna"),df_individuals.first_name+' '+df_individuals.family_name,df_individuals.family_name)

# %%
df_individuals
# Out:
#                                   name           alias_1 alias_2  \
# 0   Héctor Rusthenford Guerrero Flores     Niño Guerrero     NaN
# 1          Hermágoras González Polanco  Gordito González     NaN
# 2                        Yeico Masacre               NaN     NaN
# 3                   Genaro García Luna               NaN     NaN
# 4          Gilberto Rodríguez Orejuela  The Chess Player     NaN
# ..                                 ...               ...     ...
# 86        Miguel Angel Treviño Morales               Z40     NaN
# 87                   Diego Perez Henao    Diego Rastrojo     NaN
# 88                 Luis E. Calle Serna               NaN     NaN
# 89          Javier Antonio Calle Serna             Comba     NaN
# 90         Guillermo Leon Saenz Vargas      Alfonso Cano     NaN
#
#             first_name         family_name                 search_term
# 0   Héctor Rusthenford     Guerrero Flores             Guerrero Flores
# 1           Hermágoras    González Polanco            González Polanco
# 2                Yeico             Masacre                     Masacre
# 3               Genaro         García Luna                 García Luna
# 4             Gilberto  Rodríguez Orejuela          Rodríguez Orejuela
# ..                 ...                 ...                         ...
# 86        Miguel Angel     Treviño Morales             Treviño Morales
# 87               Diego         Perez Henao                 Perez Henao
# 88        Luis Enrique         Calle Serna    Luis Enrique Calle Serna
# 89      Javier Antonio         Calle Serna  Javier Antonio Calle Serna
# 90      Guillermo Leon        Saenz Vargas                Saenz Vargas
#
# [91 rows x 6 columns]

# %% [markdown]
# Network creation

# %%
dict_individuals = dict(zip(df_individuals.name,df_individuals.search_term))

# %%
value_combinations = list(itertools.combinations(df_individuals.name.values, 2))
df_connections = pd.DataFrame(value_combinations, columns=['ind_1','ind_2'])
df_connections['weight'] = 0
df_connections.reset_index(drop=True, inplace=True)

# %%
df_connections
# Out:
#                                    ind_1                              ind_2  \
# 0     Héctor Rusthenford Guerrero Flores        Hermágoras González Polanco
# 1     Héctor Rusthenford Guerrero Flores                      Yeico Masacre
# 2     Héctor Rusthenford Guerrero Flores                 Genaro García Luna
# 3     Héctor Rusthenford Guerrero Flores        Gilberto Rodríguez Orejuela
# 4     Héctor Rusthenford Guerrero Flores  Jobanis de Jesús Ávila Villadiego
# ...                                  ...                                ...
# 4090                   Diego Perez Henao         Javier Antonio Calle Serna
# 4091                   Diego Perez Henao        Guillermo Leon Saenz Vargas
# 4092                 Luis E. Calle Serna         Javier Antonio Calle Serna
# 4093                 Luis E. Calle Serna        Guillermo Leon Saenz Vargas
# 4094          Javier Antonio Calle Serna        Guillermo Leon Saenz Vargas
#
#       weight
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 4090       0
# 4091       0
# 4092       0
# 4093       0
# 4094       0
#
# [4095 rows x 3 columns]

# %%
for article in df_articles.text.values:
    for row in range(len(df_connections)):
        if dict_individuals[df_connections.loc[row,'ind_1']] in article and dict_individuals[df_connections.loc[row,'ind_2']] in article:
            df_connections.loc[row,'weight'] += 1

# %%
dict_sizes = {}
for name in df_individuals.name.values:
    dict_sizes[name] = 0
    for article in df_articles.text.values:
        if dict_individuals[name] in article:
            dict_sizes[name] += 1

# %% [markdown]
# ## Network visualisation

# %%
df_connections
# Out:
#                                    ind_1                              ind_2  \
# 0     Héctor Rusthenford Guerrero Flores        Hermágoras González Polanco
# 1     Héctor Rusthenford Guerrero Flores                      Yeico Masacre
# 2     Héctor Rusthenford Guerrero Flores                 Genaro García Luna
# 3     Héctor Rusthenford Guerrero Flores        Gilberto Rodríguez Orejuela
# 4     Héctor Rusthenford Guerrero Flores  Jobanis de Jesús Ávila Villadiego
# ...                                  ...                                ...
# 4090                   Diego Perez Henao         Javier Antonio Calle Serna
# 4091                   Diego Perez Henao        Guillermo Leon Saenz Vargas
# 4092                 Luis E. Calle Serna         Javier Antonio Calle Serna
# 4093                 Luis E. Calle Serna        Guillermo Leon Saenz Vargas
# 4094          Javier Antonio Calle Serna        Guillermo Leon Saenz Vargas
#
#       weight
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 4090      14
# 4091       0
# 4092      16
# 4093       0
# 4094       0
#
# [4095 rows x 3 columns]

# %%
elist = list(zip(df_connections['ind_1'],df_connections['ind_2'],df_connections['weight']))
g = nx.Graph()
g.add_weighted_edges_from([(el[0],el[1],el[2]) for el in elist if el[2]!=0])

# %%
nt = pyvis.network.Network('1500px','1500px', bgcolor="#222222", font_color="white") #,select_menu=True,filter_menu=True)
nt.barnes_hut()
nt.from_nx(g) 
nt.toggle_physics(True)

for node in nt.nodes:
    node['font']['size'] = 100
    node['shape'] = 'circularImage'
    node['image'] = f"/Users/federico.bindi/Desktop/GitHub/organized-crime-articles/_aux/pictures/{node['id']}.png"
    node['size'] = dict_sizes[node['id']]

nt.show('_out/networks/individuals.html',notebook=False)
# Out:
# _out/networks/individuals.html

# %%
nt.nodes
# Out:
# [{'color': '#97c2fc',
#   'size': 5,
#   'id': 'Héctor Rusthenford Guerrero Flores',
#   'label': 'Héctor Rusthenford Guerrero Flores',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Héctor Rusthenford Guerrero Flores.png'},
#  {'color': '#97c2fc',
#   'size': 1131,
#   'id': 'Pedro Oliverio Guerrero',
#   'label': 'Pedro Oliverio Guerrero',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Pedro Oliverio Guerrero.png'},
#  {'color': '#97c2fc',
#   'size': 37,
#   'id': 'Yeico Masacre',
#   'label': 'Yeico Masacre',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Yeico Masacre.png'},
#  {'color': '#97c2fc',
#   'size': 14,
#   'id': 'Genaro García Luna',
#   'label': 'Genaro García Luna',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Genaro García Luna.png'},
#  {'color': '#97c2fc',
#   'size': 703,
#   'id': 'Pablo Escobar',
#   'label': 'Pablo Escobar',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Pablo Escobar.png'},
#  {'color': '#97c2fc',
#   'size': 44,
#   'id': 'César Emilio Peralta',
#   'label': 'César Emilio Peralta',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/César Emilio Peralta.png'},
#  {'color': '#97c2fc',
#   'size': 98,
#   'id': 'José Adán Salazar Umaña',
#   'label': 'José Adán Salazar Umaña',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/José Adán Salazar Umaña.png'},
#  {'color': '#97c2fc',
#   'size': 22,
#   'id': 'Chapitos',
#   'label': 'Chapitos',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Chapitos.png'},
#  {'color': '#97c2fc',
#   'size': 25,
#   'id': 'Luis Agustin Caicedo Velandia',
#   'label': 'Luis Agustin Caicedo Velandia',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Luis Agustin Caicedo Velandia.png'},
#  {'color': '#97c2fc',
#   'size': 19,
#   'id': 'José Antonio Yépez Ortiz',
#   'label': 'José Antonio Yépez Ortiz',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/José Antonio Yépez Ortiz.png'},
#  {'color': '#97c2fc',
#   'size': 28,
#   'id': 'Álex Saab',
#   'label': 'Álex Saab',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Álex Saab.png'},
#  {'color': '#97c2fc',
#   'size': 54,
#   'id': 'Géner García Molina',
#   'label': 'Géner García Molina',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Géner García Molina.png'},
#  {'color': '#97c2fc',
#   'size': 49,
#   'id': 'Dámaso López Núñez',
#   'label': 'Dámaso López Núñez',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Dámaso López Núñez.png'},
#  {'color': '#97c2fc',
#   'size': 18,
#   'id': 'Óscar Mauricio Pachón',
#   'label': 'Óscar Mauricio Pachón',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Óscar Mauricio Pachón.png'},
#  {'color': '#97c2fc',
#   'size': 117,
#   'id': 'Nemesio Oseguera Cervantes',
#   'label': 'Nemesio Oseguera Cervantes',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Nemesio Oseguera Cervantes.png'},
#  {'color': '#97c2fc',
#   'size': 13,
#   'id': 'Martin Farfan Diaz Gonzalez',
#   'label': 'Martin Farfan Diaz Gonzalez',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Martin Farfan Diaz Gonzalez.png'},
#  {'color': '#97c2fc',
#   'size': 50,
#   'id': 'Fausto Isidro Meza Flores',
#   'label': 'Fausto Isidro Meza Flores',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Fausto Isidro Meza Flores.png'},
#  {'color': '#97c2fc',
#   'size': 140,
#   'id': 'Victor Navarro',
#   'label': 'Victor Navarro',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Victor Navarro.png'},
#  {'color': '#97c2fc',
#   'size': 20,
#   'id': 'Mario Ramirez Treviño',
#   'label': 'Mario Ramirez Treviño',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Mario Ramirez Treviño.png'},
#  {'color': '#97c2fc',
#   'size': 71,
#   'id': "Alejandro 'Omar' Treviño Morales",
#   'label': "Alejandro 'Omar' Treviño Morales",
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': "_aux/pictures/Alejandro 'Omar' Treviño Morales.png"},
#  {'color': '#97c2fc',
#   'size': 89,
#   'id': 'Walid Makled',
#   'label': 'Walid Makled',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Walid Makled.png'},
#  {'color': '#97c2fc',
#   'size': 808,
#   'id': 'Henry de Jesús López',
#   'label': 'Henry de Jesús López',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Henry de Jesús López.png'},
#  {'color': '#97c2fc',
#   'size': 13,
#   'id': 'Jose Eberto Lopez Montero',
#   'label': 'Jose Eberto Lopez Montero',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Jose Eberto Lopez Montero.png'},
#  {'color': '#97c2fc',
#   'size': 51,
#   'id': 'Servando Gomez Martinez',
#   'label': 'Servando Gomez Martinez',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Servando Gomez Martinez.png'},
#  {'color': '#97c2fc',
#   'size': 79,
#   'id': 'Dairo Antonio Úsuga',
#   'label': 'Dairo Antonio Úsuga',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Dairo Antonio Úsuga.png'},
#  {'color': '#97c2fc',
#   'size': 23,
#   'id': 'Victor Julio Suarez Rojas',
#   'label': 'Victor Julio Suarez Rojas',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Victor Julio Suarez Rojas.png'},
#  {'color': '#97c2fc',
#   'size': 69,
#   'id': 'Nazario Moreno Gonzalez',
#   'label': 'Nazario Moreno Gonzalez',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Nazario Moreno Gonzalez.png'},
#  {'color': '#97c2fc',
#   'size': 9,
#   'id': 'Vicente Carrillo Leyva',
#   'label': 'Vicente Carrillo Leyva',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Vicente Carrillo Leyva.png'},
#  {'color': '#97c2fc',
#   'size': 129,
#   'id': 'Vicente Carrillo Fuentes',
#   'label': 'Vicente Carrillo Fuentes',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Vicente Carrillo Fuentes.png'},
#  {'color': '#97c2fc',
#   'size': 70,
#   'id': 'Maximiliano Bonilla Orozco',
#   'label': 'Maximiliano Bonilla Orozco',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Maximiliano Bonilla Orozco.png'},
#  {'color': '#97c2fc',
#   'size': 182,
#   'id': 'Joaquín Guzmán Loera',
#   'label': 'Joaquín Guzmán Loera',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Joaquín Guzmán Loera.png'},
#  {'color': '#97c2fc',
#   'size': 90,
#   'id': 'Ismael Zambada García',
#   'label': 'Ismael Zambada García',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Ismael Zambada García.png'},
#  {'color': '#97c2fc',
#   'size': 431,
#   'id': 'Hector Beltran Leyva',
#   'label': 'Hector Beltran Leyva',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Hector Beltran Leyva.png'},
#  {'color': '#97c2fc',
#   'size': 34,
#   'id': 'Fernando Sanchez Arellano',
#   'label': 'Fernando Sanchez Arellano',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Fernando Sanchez Arellano.png'},
#  {'color': '#97c2fc',
#   'size': 33,
#   'id': 'Erickson Vargas Cardenas',
#   'label': 'Erickson Vargas Cardenas',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Erickson Vargas Cardenas.png'},
#  {'color': '#97c2fc',
#   'size': 57,
#   'id': 'Antonio Cardenas Guillen',
#   'label': 'Antonio Cardenas Guillen',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Antonio Cardenas Guillen.png'},
#  {'color': '#97c2fc',
#   'size': 187,
#   'id': 'Heriberto Lazcano',
#   'label': 'Heriberto Lazcano',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Heriberto Lazcano.png'},
#  {'color': '#97c2fc',
#   'size': 41,
#   'id': 'Daniel Barrera Barrera',
#   'label': 'Daniel Barrera Barrera',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Daniel Barrera Barrera.png'},
#  {'color': '#97c2fc',
#   'size': 71,
#   'id': 'Miguel Angel Treviño Morales',
#   'label': 'Miguel Angel Treviño Morales',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Miguel Angel Treviño Morales.png'},
#  {'color': '#97c2fc',
#   'size': 76,
#   'id': 'Diego Perez Henao',
#   'label': 'Diego Perez Henao',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Diego Perez Henao.png'},
#  {'color': '#97c2fc',
#   'size': 64,
#   'id': 'Luis E. Calle Serna',
#   'label': 'Luis E. Calle Serna',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Luis E. Calle Serna.png'},
#  {'color': '#97c2fc',
#   'size': 44,
#   'id': 'Javier Antonio Calle Serna',
#   'label': 'Javier Antonio Calle Serna',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Javier Antonio Calle Serna.png'},
#  {'color': '#97c2fc',
#   'size': 4,
#   'id': 'Hermágoras González Polanco',
#   'label': 'Hermágoras González Polanco',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Hermágoras González Polanco.png'},
#  {'color': '#97c2fc',
#   'size': 12,
#   'id': 'Samark López Bello',
#   'label': 'Samark López Bello',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Samark López Bello.png'},
#  {'color': '#97c2fc',
#   'size': 132,
#   'id': 'Tareck El Aissami',
#   'label': 'Tareck El Aissami',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Tareck El Aissami.png'},
#  {'color': '#97c2fc',
#   'size': 50,
#   'id': 'Juan Alberto Ortiz Lopez',
#   'label': 'Juan Alberto Ortiz Lopez',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Juan Alberto Ortiz Lopez.png'},
#  {'color': '#97c2fc',
#   'size': 5,
#   'id': 'Jobanis de Jesús Ávila Villadiego',
#   'label': 'Jobanis de Jesús Ávila Villadiego',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Jobanis de Jesús Ávila Villadiego.png'},
#  {'color': '#97c2fc',
#   'size': 8,
#   'id': 'Leider Johani Noscue',
#   'label': 'Leider Johani Noscue',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Leider Johani Noscue.png'},
#  {'color': '#97c2fc',
#   'size': 10,
#   'id': 'Hernán Darío Velásquez Saldarriaga',
#   'label': 'Hernán Darío Velásquez Saldarriaga',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Hernán Darío Velásquez Saldarriaga.png'},
#  {'color': '#97c2fc',
#   'size': 53,
#   'id': 'Walter Patricio Arizala',
#   'label': 'Walter Patricio Arizala',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Walter Patricio Arizala.png'},
#  {'color': '#97c2fc',
#   'size': 54,
#   'id': 'Miguel Botache Santillana',
#   'label': 'Miguel Botache Santillana',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Miguel Botache Santillana.png'},
#  {'color': '#97c2fc',
#   'size': 13,
#   'id': 'Néstor Gregorio Vera Fernández',
#   'label': 'Néstor Gregorio Vera Fernández',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Néstor Gregorio Vera Fernández.png'},
#  {'color': '#97c2fc',
#   'size': 42,
#   'id': 'Roberto Vargas Gutiérrez',
#   'label': 'Roberto Vargas Gutiérrez',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Roberto Vargas Gutiérrez.png'},
#  {'color': '#97c2fc',
#   'size': 16,
#   'id': 'Diego Fernando Murillo Bejarano',
#   'label': 'Diego Fernando Murillo Bejarano',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Diego Fernando Murillo Bejarano.png'},
#  {'color': '#97c2fc',
#   'size': 65,
#   'id': 'Rodrigo Londoño Echeverri',
#   'label': 'Rodrigo Londoño Echeverri',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Rodrigo Londoño Echeverri.png'},
#  {'color': '#97c2fc',
#   'size': 93,
#   'id': 'Horst Walther Overdick',
#   'label': 'Horst Walther Overdick',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Horst Walther Overdick.png'},
#  {'color': '#97c2fc',
#   'size': 39,
#   'id': 'Reynerio Flores Lazo',
#   'label': 'Reynerio Flores Lazo',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Reynerio Flores Lazo.png'},
#  {'color': '#97c2fc',
#   'size': 52,
#   'id': 'José Natividad Luna Pereira',
#   'label': 'José Natividad Luna Pereira',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/José Natividad Luna Pereira.png'},
#  {'color': '#97c2fc',
#   'size': 19,
#   'id': 'Juan de Dios Úsuga',
#   'label': 'Juan de Dios Úsuga',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Juan de Dios Úsuga.png'},
#  {'color': '#97c2fc',
#   'size': 63,
#   'id': 'Luciano Marín Arango',
#   'label': 'Luciano Marín Arango',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Luciano Marín Arango.png'},
#  {'color': '#97c2fc',
#   'size': 20,
#   'id': 'Gilberto Rodríguez Orejuela',
#   'label': 'Gilberto Rodríguez Orejuela',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Gilberto Rodríguez Orejuela.png'},
#  {'color': '#97c2fc',
#   'size': 11,
#   'id': 'José Bayron Piedrahita Ceballos',
#   'label': 'José Bayron Piedrahita Ceballos',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/José Bayron Piedrahita Ceballos.png'},
#  {'color': '#97c2fc',
#   'size': 39,
#   'id': 'Gustavo Aníbal Giraldo',
#   'label': 'Gustavo Aníbal Giraldo',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Gustavo Aníbal Giraldo.png'},
#  {'color': '#97c2fc',
#   'size': 12,
#   'id': 'Jorge Eduardo Costilla Sánchez',
#   'label': 'Jorge Eduardo Costilla Sánchez',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Jorge Eduardo Costilla Sánchez.png'},
#  {'color': '#97c2fc',
#   'size': 34,
#   'id': 'Nicolás Rodríguez Bautista',
#   'label': 'Nicolás Rodríguez Bautista',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Nicolás Rodríguez Bautista.png'},
#  {'color': '#97c2fc',
#   'size': 37,
#   'id': 'Ariel Máximo Cantero',
#   'label': 'Ariel Máximo Cantero',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Ariel Máximo Cantero.png'},
#  {'color': '#97c2fc',
#   'size': 21,
#   'id': 'Jarvis Chimenes Pavão',
#   'label': 'Jarvis Chimenes Pavão',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Jarvis Chimenes Pavão.png'},
#  {'color': '#97c2fc',
#   'size': 16,
#   'id': 'Seuxis Pausías Hernández',
#   'label': 'Seuxis Pausías Hernández',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Seuxis Pausías Hernández.png'},
#  {'color': '#97c2fc',
#   'size': 8,
#   'id': 'Marcos de Jesus Figueroa Garcia',
#   'label': 'Marcos de Jesus Figueroa Garcia',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Marcos de Jesus Figueroa Garcia.png'},
#  {'color': '#97c2fc',
#   'size': 15,
#   'id': 'Rafael Alvarez Piñeda',
#   'label': 'Rafael Alvarez Piñeda',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Rafael Alvarez Piñeda.png'},
#  {'color': '#97c2fc',
#   'size': 32,
#   'id': 'Guillermo Leon Saenz Vargas',
#   'label': 'Guillermo Leon Saenz Vargas',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Guillermo Leon Saenz Vargas.png'},
#  {'color': '#97c2fc',
#   'size': 6,
#   'id': 'Angel de Jesus Pacheco Chanci',
#   'label': 'Angel de Jesus Pacheco Chanci',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Angel de Jesus Pacheco Chanci.png'},
#  {'color': '#97c2fc',
#   'size': 8,
#   'id': 'Cesar Augusto Torres Lujan',
#   'label': 'Cesar Augusto Torres Lujan',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Cesar Augusto Torres Lujan.png'},
#  {'color': '#97c2fc',
#   'size': 5,
#   'id': 'José Manuel Sierra Sabogal',
#   'label': 'José Manuel Sierra Sabogal',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/José Manuel Sierra Sabogal.png'},
#  {'color': '#97c2fc',
#   'size': 6,
#   'id': 'José Vicente Lesmes',
#   'label': 'José Vicente Lesmes',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/José Vicente Lesmes.png'},
#  {'color': '#97c2fc',
#   'size': 7,
#   'id': 'Henry Castellanos Garzón',
#   'label': 'Henry Castellanos Garzón',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Henry Castellanos Garzón.png'},
#  {'color': '#97c2fc',
#   'size': 8,
#   'id': 'Eliecer Erlinto Chamorro',
#   'label': 'Eliecer Erlinto Chamorro',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Eliecer Erlinto Chamorro.png'},
#  {'color': '#97c2fc',
#   'size': 8,
#   'id': 'Gilberto Aparecido Dos Santos',
#   'label': 'Gilberto Aparecido Dos Santos',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Gilberto Aparecido Dos Santos.png'},
#  {'color': '#97c2fc',
#   'size': 29,
#   'id': 'Marcos Willians Herbas Camacho',
#   'label': 'Marcos Willians Herbas Camacho',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Marcos Willians Herbas Camacho.png'},
#  {'color': '#97c2fc',
#   'size': 7,
#   'id': 'Francisco Zeledon',
#   'label': 'Francisco Zeledon',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Francisco Zeledon.png'},
#  {'color': '#97c2fc',
#   'size': 14,
#   'id': 'Amauri Carmona Morelos',
#   'label': 'Amauri Carmona Morelos',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/Amauri Carmona Morelos.png'},
#  {'color': '#97c2fc',
#   'size': 4,
#   'id': 'José Jesús Méndez Vargas',
#   'label': 'José Jesús Méndez Vargas',
#   'shape': 'circularImage',
#   'font': {'color': 'white', 'size': 100},
#   'image': '_aux/pictures/José Jesús Méndez Vargas.png'}]

# %% [markdown]
# # Groups

# %% [markdown]
# ## Network preparation

# %% [markdown]
# ## Network visualisation
